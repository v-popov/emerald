# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#
#     Linking successful
#     /home/ddhar/miniconda3/envs/emerald/lib/python3.7/site-packages/en_core_web_sm
#     -->
#     /home/ddhar/miniconda3/envs/emerald/lib/python3.7/site-packages/spacy/data/en_core_web_sm
#
#     You can now load the model via spacy.load('en_core_web_sm')

# %%
import numpy as np
import pandas as pd
from pprint import pprint

import emerald

# %% [markdown]
# ## Load sample data

# %%
table_1 = pd.read_csv("data/sample_1.csv")
print("Rows:    {:4d}".format(table_1.shape[0]))
print("Columns: {:4d}".format(table_1.shape[1]))
table_1.head()
# Out:
# Rows:     500
# Columns:   10
#                CCID                ACCOUNT TYPE        SSN GIVEN NAME  \
# 0  9000007856409346      HIGH INTEREST CHECKING  805004325      JANIS
# 1  9000007787145712  CitiGold Interest Checking  806008628     CHERYL
# 2  9000007789022796                   4 YEAR CD  920812461     ARTHUR
# 3  9000007854230503   EQUITY SOURCE-RESIDENTIAL  909159250      SIGNE
# 4  9000007838746616                   VISA CARD  989851692       ALMA
#
#   LAST NAME        PHYSICAL ADDRESS              CITY STATE  POSTAL CODE  \
# 0     WELLS      142 WINTERSTEIN DR            FOLSOM    CA        95630
# 1     ISKIN        1763 RED ROCK CT  WESTLAKE VILLAGE    CA        91362
# 2  MATYURIN  25935 ROLLING HILLS RD          TORRANCE    CA        90505
# 3    BAZILE          892 SPRING AVE         UNIONDALE    NY        11553
# 4  THURTELL           29 VILLAGE CV           WARWICK    NY        10990
#
#    GENDER
# 0  Female
# 1    Male
# 2  Female
# 3    Male
# 4    Male

# %%
table_2 = pd.read_csv("data/sample_2.csv")
print("Rows:    {:4d}".format(table_2.shape[0]))
print("Columns: {:4d}".format(table_2.shape[1]))
table_2.head()
# Out:
# Rows:     424
# Columns:   10
#                CCID                     UPOF_LONG_NME P_GIVEN_NAME_ONE  \
# 0  9000007851316825                  REGULAR CHECKING             JEAN
# 1  9000007835845068  Citibank(R) Savings Plus Account          CHARLES
# 2  9000007862175441  Citibank(R) Savings Plus Account             KYRA
# 3  9000007848068215                  REGULAR CHECKING          WILLIAM
# 4  9000007820188961        CitiGold Interest Checking            LORNA
#
#   P_LAST_NAME P_PHYSICAL_ADDR_LINE_ONE P_PHYSICAL_CITY_NAME  \
# 0    HAMILTON      813 W WHITTIER BLVD           MONTEBELLO
# 1     NEGRETE           4166 ALMOND ST            RIVERSIDE
# 2       DRAKE            147 MILLER RD              PRESTON
# 3       JONES         2044 CROPSEY AVE             BROOKLYN
# 4      CAMPOS    2S653 PIERRE CURIE LN          WARRENVILLE
#
#   P_PHYSICAL_PROVINCE_STATE_NAME  P_PHYSICAL_POSTAL_CODE      P_RACE_NAME  \
# ...

# %%
table_3 = pd.read_csv("data/sample_3.csv")
print("Rows:    {:4d}".format(table_3.shape[0]))
print("Columns: {:4d}".format(table_3.shape[1]))
table_3.head()
# Out:
# Rows:    1000
# Columns:   14
#       Institution Name                      Branch Name Established Date  \
# 0  JPMorgan Chase Bank                    Renton Branch       10/20/1961
# 1  JPMorgan Chase Bank      Preston and Beltline Branch       11/06/2008
# 2  JPMorgan Chase Bank  Hyde Park Banking Center Branch       12/15/2003
# 3  JPMorgan Chase Bank                 Nesconset Branch       04/17/1974
# 4  JPMorgan Chase Bank                      Novi Branch       05/28/1956
#
#              Street Address       City   County State  Zipcode  Latitude  \
# 0    150 Logan Avenue South     Renton     King    WA    98057  47.48138
# 1          15114 Preston Rd     Dallas   Dallas    TX    75248  32.95420
# 2     1204 East 53rd Street    Chicago     Cook    IL    60615  41.79954
# 3      705 Smithtown Bypass  Smithtown  Suffolk    NY    11787  40.81819
# 4  43100 Grand River Avenue       Novi  Oakland    MI    48375  42.48002
#
# ...

# %%
table_4 = pd.read_csv("data/sample_4.csv")
print("Rows:    {:4d}".format(table_4.shape[0]))
print("Columns: {:4d}".format(table_4.shape[1]))
table_4.head()
# Out:
# Rows:    1000
# Columns:   15
#            institution                           branch        date  \
# 0  JPMorgan Chase Bank                    Renton Branch  10/20/1961
# 1  JPMorgan Chase Bank      Preston and Beltline Branch  11/06/2008
# 2  JPMorgan Chase Bank  Hyde Park Banking Center Branch  12/15/2003
# 3  JPMorgan Chase Bank                 Nesconset Branch  04/17/1974
# 4  JPMorgan Chase Bank                      Novi Branch  05/28/1956
#
#                 street_name  city_name county_name state_name    Zip  \
# 0    150 Logan Avenue South     Renton        King         WA  98057
# 1          15114 Preston Rd     Dallas      Dallas         TX  75248
# 2     1204 East 53rd Street    Chicago        Cook         IL  60615
# 3      705 Smithtown Bypass  Smithtown     Suffolk         NY  11787
# 4  43100 Grand River Avenue       Novi     Oakland         MI  48375
#
#         Lat       Long  Deposits_2013  Deposits_2014  Deposits_2015  \
# ...

# %% [markdown]
# ## Process data

# %%
emerald.process_table(table_4, max_sample_size=10)
# Out:
# [{'column_name': 'institution',
#   'data_class': 'name_or_address',
#   'vector': <1x74088 sparse matrix of type '<class 'numpy.float32'>'
#   	with 17 stored elements in Compressed Sparse Row format>},
#  {'column_name': 'branch',
#   'data_class': 'text',
#   'vector': <1x74088 sparse matrix of type '<class 'numpy.float32'>'
#   	with 153 stored elements in Compressed Sparse Row format>},
#  {'column_name': 'date',
#   'data_class': 'numeric_or_id',
#   'regex': '^\\d{2}/\\d{2}/\\d{4}$'},
#  {'column_name': 'street_name',
#   'data_class': 'name_or_address',
#   'vector': <1x74088 sparse matrix of type '<class 'numpy.float32'>'
#   	with 155 stored elements in Compressed Sparse Row format>},
#  {'column_name': 'city_name',
#   'data_class': 'name_or_address',
#   'vector': <1x74088 sparse matrix of type '<class 'numpy.float32'>'
#   	with 85 stored elements in Compressed Sparse Row format>},
#  {'column_name': 'county_name',
#   'data_class': 'name_or_address',
# ...
