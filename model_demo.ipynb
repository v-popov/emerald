# %% [markdown]
# # Emerald Model Demo
# The purpose of this notebook is to demonstrate how the Emerald algorithms process data internally.
# The Emerald model has two primary functions:
#
# - __Process:__ Given a database table, this function processes each column by finding its data classification (`named_entity`, `numeric_or_id` or `text`) and computing a PII-free representation which can be used for similarity comparisons.
# - __Search:__ Given a valid query of a column name, this function finds all the columns which contain similar data to the query column.
#
# We provide 4 sample datasets containing similar columns for evaluating the effectiveness of our model.

# %% [markdown]
# ## Imports & Installs

# %%
#!python -m spacy download en_core_web_sm

# %%
import pandas as pd
import emerald

# %% [markdown]
# ## Load sample data

# %%
sample_tables = {}
sample_tables["table_1"] = pd.read_csv("data/sample_1.csv")
sample_tables["table_2"] = pd.read_csv("data/sample_2.csv")
sample_tables["table_3"] = pd.read_csv("data/sample_3.csv")
sample_tables["table_4"] = pd.read_csv("data/sample_4.csv")

# %%
print("SAMPLE TABLE 1")
print("--------------")
print("Rows:    {:4d}".format(sample_tables["table_1"].shape[0]))
print("Columns: {:4d}".format(sample_tables["table_1"].shape[1]))
sample_tables["table_1"].head()
# Out:
# SAMPLE TABLE 1
# --------------
# Rows:     500
# Columns:   10
#                CCID                ACCOUNT TYPE        SSN GIVEN NAME  \
# 0  9000007856409346      HIGH INTEREST CHECKING  805004325      JANIS
# 1  9000007787145712  CitiGold Interest Checking  806008628     CHERYL
# 2  9000007789022796                   4 YEAR CD  920812461     ARTHUR
# 3  9000007854230503   EQUITY SOURCE-RESIDENTIAL  909159250      SIGNE
# 4  9000007838746616                   VISA CARD  989851692       ALMA
#
#   LAST NAME        PHYSICAL ADDRESS              CITY STATE  POSTAL CODE  \
# 0     WELLS      142 WINTERSTEIN DR            FOLSOM    CA        95630
# 1     ISKIN        1763 RED ROCK CT  WESTLAKE VILLAGE    CA        91362
# 2  MATYURIN  25935 ROLLING HILLS RD          TORRANCE    CA        90505
# 3    BAZILE          892 SPRING AVE         UNIONDALE    NY        11553
# 4  THURTELL           29 VILLAGE CV           WARWICK    NY        10990
#
#    GENDER
# 0  Female
# 1    Male
# 2  Female
# 3    Male
# 4    Male

# %%
print("SAMPLE TABLE 2")
print("--------------")
print("Rows:    {:4d}".format(sample_tables["table_2"].shape[0]))
print("Columns: {:4d}".format(sample_tables["table_2"].shape[1]))
sample_tables["table_2"].head()
# Out:
# SAMPLE TABLE 2
# --------------
# Rows:     424
# Columns:   11
#            CCID                     UPOF_LONG_NME P_GIVEN_NAME_ONE  \
# 0  9.000010e+15                  REGULAR CHECKING             JEAN
# 1  9.000010e+15  Citibank(R) Savings Plus Account          CHARLES
# 2  9.000010e+15  Citibank(R) Savings Plus Account             KYRA
# 3  9.000010e+15                  REGULAR CHECKING          WILLIAM
# 4  9.000010e+15        CitiGold Interest Checking            LORNA
#
#   P_LAST_NAME SOCIAL_SECURITY P_PHYSICAL_ADDR_LINE_ONE P_PHYSICAL_CITY_NAME  \
# 0    HAMILTON     178-28-3635      813 W WHITTIER BLVD           MONTEBELLO
# 1     NEGRETE     435-41-1162           4166 ALMOND ST            RIVERSIDE
# 2       DRAKE     319-77-3993            147 MILLER RD              PRESTON
# 3       JONES     757-94-0576         2044 CROPSEY AVE             BROOKLYN
# 4      CAMPOS     356-82-4395    2S653 PIERRE CURIE LN          WARRENVILLE
#
#   P_PHYSICAL_PROVINCE_STATE_NAME  P_PHYSICAL_POSTAL_CODE      P_RACE_NAME  \
# 0                             CA                   90640  American Indian
# 1                             CA                   92501            White
# 2                             CT                   63658            Asian
# 3                             NY                   11214  Native Hawaiian
# 4                             IL                   60555            White
#
#    P_GEND
# 0   Other
# 1  Female
# 2  Female
# 3    Male
# 4    Male

# %%
print("SAMPLE TABLE 3")
print("--------------")
print("Rows:    {:4d}".format(sample_tables["table_3"].shape[0]))
print("Columns: {:4d}".format(sample_tables["table_3"].shape[1]))
sample_tables["table_3"].head()
# Out:
# SAMPLE TABLE 3
# --------------
# Rows:    1000
# Columns:   14
#       Institution Name                      Branch Name Established Date  \
# 0  JPMorgan Chase Bank                    Renton Branch       10/20/1961
# 1  JPMorgan Chase Bank      Preston and Beltline Branch       11/06/2008
# 2  JPMorgan Chase Bank  Hyde Park Banking Center Branch       12/15/2003
# 3  JPMorgan Chase Bank                 Nesconset Branch       04/17/1974
# 4  JPMorgan Chase Bank                      Novi Branch       05/28/1956
#
#              Street Address       City   County State  Zipcode  Latitude  \
# 0    150 Logan Avenue South     Renton     King    WA    98057  47.48138
# 1          15114 Preston Rd     Dallas   Dallas    TX    75248  32.95420
# 2     1204 East 53rd Street    Chicago     Cook    IL    60615  41.79954
# 3      705 Smithtown Bypass  Smithtown  Suffolk    NY    11787  40.81819
# 4  43100 Grand River Avenue       Novi  Oakland    MI    48375  42.48002
#
#    Longitude  2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits
# 0 -122.20911        73082.0        73952.0        75749.0        72068.0
# 1  -96.80397         7119.0        11684.0        22178.0        22365.0
# 2  -87.59649        49952.0        57415.0        65144.0        79133.0
# 3  -73.21205        23114.0        26757.0        32616.0        37519.0
# 4  -83.47205       137078.0       145409.0       165753.0       181205.0

# %%
print("SAMPLE TABLE 4")
print("--------------")
print("Rows:    {:4d}".format(sample_tables["table_4"].shape[0]))
print("Columns: {:4d}".format(sample_tables["table_4"].shape[1]))
sample_tables["table_4"].head()
# Out:
# SAMPLE TABLE 4
# --------------
# Rows:    1000
# Columns:   15
#            institution                           branch        date  \
# 0  JPMorgan Chase Bank                    Renton Branch  10/20/1961
# 1  JPMorgan Chase Bank      Preston and Beltline Branch  11/06/2008
# 2  JPMorgan Chase Bank  Hyde Park Banking Center Branch  12/15/2003
# 3  JPMorgan Chase Bank                 Nesconset Branch  04/17/1974
# 4  JPMorgan Chase Bank                      Novi Branch  05/28/1956
#
#                 street_name  city_name county_name state_name    Zip  \
# 0    150 Logan Avenue South     Renton        King         WA  98057
# 1          15114 Preston Rd     Dallas      Dallas         TX  75248
# 2     1204 East 53rd Street    Chicago        Cook         IL  60615
# 3      705 Smithtown Bypass  Smithtown     Suffolk         NY  11787
# 4  43100 Grand River Avenue       Novi     Oakland         MI  48375
#
#         Lat       Long  Deposits_2013  Deposits_2014  Deposits_2015  \
# 0  47.48138 -122.20911        72068.0        74047.0        81847.0
# 1  32.95420  -96.80397        22365.0        26223.0        62303.0
# 2  41.79954  -87.59649        79133.0        91040.0       108448.0
# 3  40.81819  -73.21205        37519.0        48314.0        58648.0
# 4  42.48002  -83.47205       181205.0       202553.0       216597.0
#
#    Deposits_2016              race
# 0          91001   American Indian
# 1          65061             Asian
# 2         125273  African American
# 3          65908   American Indian
# 4         259478             Asian

# %% [markdown]
# ## Process
# Here we demonstrate the primary function utilized by the __Emerald CLI__. As shown below, the model finds the data classification `data_class` for each column and a representation which is either a sparse vector of n-gram weights for `named_entity` or `text` data, or a regular expression for `numeric_or_id` data. The generated results are sent over for storage to the __Emerald Web Service__.

# %%
# Process all sample tables
results = []
for table_name, table_data in sample_tables.items():
    results.extend(emerald.process(table_data, max_sample_size=10, 
                                   identifiers={"table_name": table_name}))
emerald_internal_data = pd.DataFrame(results)
emerald_internal_data
# Out:
#                        column_name     data_class  \
# 0                             CCID  numeric_or_id
# 1                     ACCOUNT TYPE           text
# 2                              SSN  numeric_or_id
# 3                       GIVEN NAME   named_entity
# 4                        LAST NAME   named_entity
# 5                 PHYSICAL ADDRESS   named_entity
# 6                             CITY   named_entity
# 7                            STATE   named_entity
# 8                      POSTAL CODE  numeric_or_id
# 9                           GENDER           text
# 10                            CCID  numeric_or_id
# 11                   UPOF_LONG_NME           text
# 12                P_GIVEN_NAME_ONE   named_entity
# 13                     P_LAST_NAME           text
# 14                 SOCIAL_SECURITY  numeric_or_id
# 15        P_PHYSICAL_ADDR_LINE_ONE   named_entity
# 16            P_PHYSICAL_CITY_NAME   named_entity
# 17  P_PHYSICAL_PROVINCE_STATE_NAME   named_entity
# 18          P_PHYSICAL_POSTAL_CODE  numeric_or_id
# 19                     P_RACE_NAME           text
# 20                          P_GEND           text
# 21                Institution Name   named_entity
# 22                     Branch Name   named_entity
# 23                Established Date  numeric_or_id
# 24                  Street Address   named_entity
# 25                            City   named_entity
# 26                          County   named_entity
# 27                           State           text
# 28                         Zipcode  numeric_or_id
# 29                        Latitude  numeric_or_id
# 30                       Longitude  numeric_or_id
# 31                   2010 Deposits  numeric_or_id
# 32                   2011 Deposits  numeric_or_id
# 33                   2012 Deposits  numeric_or_id
# 34                   2013 Deposits  numeric_or_id
# 35                     institution           text
# 36                          branch           text
# 37                            date  numeric_or_id
# 38                     street_name   named_entity
# 39                       city_name   named_entity
# 40                     county_name   named_entity
# 41                      state_name           text
# 42                             Zip  numeric_or_id
# 43                             Lat  numeric_or_id
# 44                            Long  numeric_or_id
# 45                   Deposits_2013  numeric_or_id
# 46                   Deposits_2014  numeric_or_id
# 47                   Deposits_2015  numeric_or_id
# 48                   Deposits_2016  numeric_or_id
# 49                            race           text
#
#                                        representation table_name
# 0                                            ^\d{16}$    table_1
# 1     (0, 53)\t1.0\n  (0, 86)\t1.0\n  (0, 515)\t1....    table_1
# 2                                             ^\d{9}$    table_1
# 3     (0, 540)\t1.0\n  (0, 550)\t1.0\n  (0, 582)\t...    table_1
# 4     (0, 193)\t1.0\n  (0, 473)\t1.0\n  (0, 481)\t...    table_1
# 5     (0, 256)\t1.0\n  (0, 456)\t1.0\n  (0, 540)\t...    table_1
# 6     (0, 266)\t1.0\n  (0, 512)\t1.0\n  (0, 548)\t...    table_1
# 7     (0, 1524)\t1.0\n  (0, 1525)\t1.0\n  (0, 1527...    table_1
# 8                                             ^\d{5}$    table_1
# 9     (0, 466)\t1.0\n  (0, 7560)\t1.0\n  (0, 8573)...    table_1
# 10                              ^9000010000000000\.0$    table_2
# 11    (0, 53)\t1.0\n  (0, 86)\t1.0\n  (0, 515)\t1....    table_2
# 12    (0, 46)\t1.0\n  (0, 540)\t1.0\n  (0, 550)\t1...    table_2
# 13    (0, 549)\t1.0\n  (0, 550)\t1.0\n  (0, 582)\t...    table_2
# 14                              ^\d{3}\-\d{2}\-\d{4}$    table_2
# 15    (0, 215)\t1.0\n  (0, 476)\t1.0\n  (0, 481)\t...    table_2
# 16    (0, 101)\t1.0\n  (0, 266)\t1.0\n  (0, 508)\t...    table_2
# 17    (0, 1515)\t1.0\n  (0, 1525)\t1.0\n  (0, 3564...    table_2
# 18                                            ^\d{5}$    table_2
# 19    (0, 94)\t1.0\n  (0, 227)\t1.0\n  (0, 344)\t1...    table_2
# 20    (0, 466)\t1.0\n  (0, 7560)\t1.0\n  (0, 7806)...    table_2
# 21    (0, 556)\t1.0\n  (0, 582)\t1.0\n  (0, 760)\t...    table_3
# 22    (0, 110)\t1.0\n  (0, 130)\t1.0\n  (0, 424)\t...    table_3
# 23                                ^\d{2}/\d{2}/\d{4}$    table_3
# 24    (0, 349)\t1.0\n  (0, 473)\t1.0\n  (0, 475)\t...    table_3
# 25    (0, 266)\t1.0\n  (0, 473)\t1.0\n  (0, 546)\t...    table_3
# 26    (0, 424)\t1.0\n  (0, 552)\t1.0\n  (0, 722)\t...    table_3
# 27    (0, 1086)\t1.0\n  (0, 1531)\t1.0\n  (0, 3564...    table_3
# 28                                            ^\d{5}$    table_3
# 29                                   ^\d{2}\.\d{4,5}$    table_3
# 30                                 ^\-\d{2,3}\.\d{5}$    table_3
# 31                                           ^\d+\.0$    table_3
# 32                                           ^\d+\.0$    table_3
# 33                                           ^\d+\.0$    table_3
# 34                                           ^\d+\.0$    table_3
# 35    (0, 556)\t1.0\n  (0, 582)\t1.0\n  (0, 760)\t...    table_4
# 36    (0, 110)\t1.0\n  (0, 130)\t1.0\n  (0, 424)\t...    table_4
# 37                                ^\d{2}/\d{2}/\d{4}$    table_4
# 38    (0, 349)\t1.0\n  (0, 473)\t1.0\n  (0, 475)\t...    table_4
# 39    (0, 266)\t1.0\n  (0, 473)\t1.0\n  (0, 546)\t...    table_4
# 40    (0, 424)\t1.0\n  (0, 552)\t1.0\n  (0, 722)\t...    table_4
# 41    (0, 1086)\t1.0\n  (0, 1531)\t1.0\n  (0, 3564...    table_4
# 42                                            ^\d{5}$    table_4
# 43                                       ^\d{2}\.\d+$    table_4
# 44                                   ^\-\d{2,3}\.\d+$    table_4
# 45                                           ^\d+\.0$    table_4
# 46                                           ^\d+\.0$    table_4
# 47                                           ^\d+\.0$    table_4
# 48                                              ^\d+$    table_4
# 49    (0, 227)\t1.0\n  (0, 508)\t1.0\n  (0, 582)\t...    table_4

# %% [markdown]
# ## Search
# This similarity search function is run by the __Emerald Web Service__ to find all similar columns to a chosen query column. The results are filtered by a predefined score threshold, which is in turn separated into High, Medium or Low matches by the __Emerald Web Service__.

# %%
# Enter query here
query = "GENDER"

# Only run the query if it is a previously seen column name. 
# There is a validity check for this in the search bar of the frontend UI of the Emerald Web Service
if query in emerald_internal_data["column_name"].values:
    print(pd.DataFrame(emerald.search(query, emerald_internal_data, threshold=0.7)))
else:
    print("Invalid query. Please enter a valid column name.")
# Out:
#   column_name  score table_name
# 0      GENDER   1.00    table_1
# 1      P_GEND   0.82    table_2

# %%
# Enter query here
query = "CITY"

# Only run the query if it is a previously seen column name. 
# There is a validity check for this in the search bar of the frontend UI of the Emerald Web Service
if query in emerald_internal_data["column_name"].values:
    print(pd.DataFrame(emerald.search(query, emerald_internal_data, threshold=0.7)))
else:
    print("Invalid query. Please enter a valid column name.")
# Out:
#             column_name  score table_name
# 0                  CITY   1.00    table_1
# 1  P_PHYSICAL_CITY_NAME   0.96    table_2
# 2                  City   0.93    table_3
# 3             city_name   0.93    table_4

# %%
# Enter query here
query = "SSN"

# Only run the query if it is a previously seen column name. 
# There is a validity check for this in the search bar of the frontend UI of the Emerald Web Service
if query in emerald_internal_data["column_name"].values:
    print(pd.DataFrame(emerald.search(query, emerald_internal_data, threshold=0.7)))
else:
    print("Invalid query. Please enter a valid column name.")
# Out:
#        column_name  score table_name
# 0              SSN   1.00    table_1
# 1  SOCIAL_SECURITY   0.82    table_2
